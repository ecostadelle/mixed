# %%
import numpy as np
import pandas as pd
import time
import warnings

from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import KBinsDiscretizer, StandardScaler, MinMaxScaler, Normalizer, OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier

from tableshift import get_dataset
from tableshift.core.features import PreprocessorConfig
from tableshift.core.tasks import get_task_config
from ud_bagging import UDBaggingClassifier, balanced_weight_vector
from ud_naive_bayes import InterpretableBernoulliNB, InterpretableMultinomialNB, InterpretableCategoricalNB


from util import *

drop_columns = {
    'anes': ['VCF0901b'],
    'acsfoodstamps': ['ST'],
    'acsincome': ['ST']
}

data = [
    [ 'ASSISTments',             'assistments'             ],
    [ 'Childhood Lead',          'nhanes_lead'             ],
    [ 'College Scorecard',       'college_scorecard'       ], 
    [ 'Diabetes',                'brfss_diabetes'          ],
    [ 'FICO HELOC',              'heloc'                   ],
    [ 'Food Stamps',             'acsfoodstamps'           ],
    [ 'Hospital Readmission',    'diabetes_readmission'    ],    
    [ 'Hypertension',            'brfss_blood_pressure'    ],    
    #[ 'ICU Length of Stay'       'mimic_extract_los_3'     ],    
    #[ 'ICU Mortality',           'mimic_extract_mort_hosp' ],        
    [ 'Income',                  'acsincome'               ],
    #[ 'Public Health Insurance', 'acspubcov'               ],
    [ 'Sepsis',                  'physionet'               ],
    [ 'Unemployment',            'acsunemployment'         ],
    [ 'Voting',                  'anes'                    ]
    ]

df_result = {
    'acc': create_table(np.array(data)[:,1]),
    'f-1': create_table(np.array(data)[:,1])}

df_result['acc'].iloc[:,0] = np.array(data)[:,0]
df_result['f-1'].iloc[:,0] = np.array(data)[:,0]

cols = df_result['acc'].columns

dataset,identifier = ['Hospital Readmission','diabetes_readmission']

dset = get_dataset(
    name=identifier,
    initialize_data=False,
    use_cached=True
)

X_a, y_a, _, _ = dset.get_pandas('train')
X_id, y_id, _, _ = dset.get_pandas('id_test')
X_b, y_b, _, _ = dset.get_pandas('ood_test')

drop=False
fillna = False
sqrt_=int(np.sqrt(X_a.shape[1]))
log2_=int(np.log2(X_a.shape[1]))

balanced = True

X_a.reset_index(drop=True, inplace=True)
X_id.reset_index(drop=True, inplace=True)
X_b.reset_index(drop=True, inplace=True)

y_a.reset_index(drop=True, inplace=True)
y_id.reset_index(drop=True, inplace=True)
y_b.reset_index(drop=True, inplace=True)

if drop and identifier in drop_columns.keys():
    X_a.drop(drop_columns[identifier], inplace=True, axis=1, errors='ignore')
    X_id.drop(drop_columns[identifier], inplace=True, axis=1, errors='ignore')
    X_b.drop(drop_columns[identifier], inplace=True, axis=1, errors='ignore')

cat_dict = {
    f.name: f.value_mapping
    for f in get_task_config(identifier).feature_list.features 
    if f.kind.__name__ == 'CategoricalDtype' 
    and not f.is_target 
    and f.name in X_a.columns
}

cat_hidden = {
    f.name
    for f in get_task_config(identifier).feature_list.features 
    if f.kind.__name__ != 'CategoricalDtype' 
    and not f.is_target 
    and f.value_mapping 
    and f.name in X_a.columns
}

cat_feats = set(cat_dict.keys())
obj_feats = set(X_a.columns[X_a.dtypes == 'object']) - cat_feats
num_feats = set(X_a.columns) - obj_feats - cat_feats - cat_hidden

for feat in num_feats:
    try:
        out,bins = pd.qcut(X_a[feat],5,retbins=True,duplicates='drop')
        X_a[feat] = out
        X_id[feat] = pd.cut(X_id[feat],bins)
        X_b[feat] = pd.cut(X_b[feat],bins)
    except:
        print(feat)

for feat in cat_feats:
    if cat_dict[feat]:
        try:
            cat_type = pd.CategoricalDtype(categories={v: float(k) for k,v in cat_dict[feat].items()})
        except:
            cat_type = pd.CategoricalDtype(categories={k: v for k,v in cat_dict[feat].items()})
    else:
        cat_type = X_a[feat].astype(str).astype('category').dtype
    X_a[feat] = X_a[feat].astype(cat_type)
    X_id[feat] = X_id[feat].astype(cat_type)
    X_b[feat] = X_b[feat].astype(cat_type)

# Verify if all features are categories
verify = X_a.columns[X_a.dtypes != 'category']
if len(verify) > 0:
    for feat in verify:
        try:
            out,bins = pd.qcut(X_a[feat],5,retbins=True,duplicates='drop')
            X_a[feat] = out
            X_id[feat] = pd.cut(X_id[feat],bins)
            X_b[feat] = pd.cut(X_b[feat],bins)
        except:
            print(feat)

# %%
X_a = X_a.apply(lambda Xj: Xj.cat.codes)
X_id = X_id.apply(lambda Xj: Xj.cat.codes)
X_b = X_b.apply(lambda Xj: Xj.cat.codes)

# %%
model = UDBaggingClassifier(
    estimator=InterpretableCategoricalNB(
        min_categories=2, 
        alpha=1e-10, 
        force_alpha=True
    ),
    n_estimators=500, max_features=sqrt_, 
    n_jobs=-1, random_state=2
)

if balanced:
    sample_weight=balanced_weight_vector(y_a)
else:
    sample_weight=None

model.fit(X_a.values, y_a.values, sample_weight=sample_weight)

y_hat_id = model.predict(X_id.values)
acc_id = accuracy_score(y_id.values, y_hat_id)
f1_id = f1_score(y_id.values, y_hat_id)
f1_ood = None

df_result['acc'].loc[identifier,cols[1]] = acc_id
df_result['f-1'].loc[identifier,cols[1]] = f1_id

y_hat_b = model.predict(X_b.values)

acc_ood = accuracy_score(y_b.values, y_hat_b)
f1_ood = f1_score(y_b.values, y_hat_b)

df_result['acc'].loc[identifier,cols[2]] = acc_ood
df_result['f-1'].loc[identifier,cols[2]] = f1_ood

if f1_ood > 0:
    
    dbcp_a = model._dbcp(X_id.values)
    dbcp_b = model._dbcp(X_b.values)
    
    mssf_a = model.sufficiency_based_feature_importances(X_id.values)
    mssf_b = model.sufficiency_based_feature_importances(X_b.values)
    
    strategies = [dbcp_b, dbcp_b-dbcp_a, mssf_b, mssf_b-mssf_a]
    
    for i,s in enumerate(strategies):

        min, max = s.min(), s.max()
        w = (s-min)/(max-min)
        p = w/w.sum()
        model_adapted_brs = UDBaggingClassifier(
            estimator=InterpretableCategoricalNB(
                min_categories=2, 
                alpha=1e-10, 
                force_alpha=True
            ),
            n_estimators=500, max_features=sqrt_, 
            n_jobs=-1, random_state=2, 
            biased_subspaces=True, feature_bias=p
        )
        
        model_adapted_brs.fit(X_a.values, y_a, sample_weight=sample_weight)
        y_hat = model_adapted_brs.predict(X_b.values)
        acc_oodi = accuracy_score(y_b.values, y_hat)
        f1_oodi = f1_score(y_b.values, y_hat)
        
        df_result['acc'].loc[identifier,cols[i+3]] = acc_oodi
        df_result['f-1'].loc[identifier,cols[i+3]] = f1_oodi
# Out:
# 5302.53s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5302.70s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5302.89s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5303.06s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5303.24s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5303.42s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5303.59s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5303.76s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5303.94s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5304.12s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5304.29s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5304.47s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5304.65s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5304.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5305.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5305.17s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5305.35s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5305.52s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5305.70s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5305.88s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5306.05s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5306.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5306.41s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 5306.58s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/fslab/github/mixed/.venv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/home/fslab/github/mixed/.venv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/fslab/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#   File "/home/fslab/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/fslab/github/mixed/.venv/lib/python3.9/site-packages/sklearn/utils/parallel.py", line 129, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/fslab/github/mixed/ud_bagging.py", line 121, in parallel_compute_feature_importances
#     importances[features] += estimator._dbcp(X.iloc[:, features]
#   File "/home/fslab/github/mixed/ud_naive_bayes.py", line 511, in _dbcp
#     importances[:,j] += np.abs(p[0] - p[1])[Xj]*valid
# IndexError: index 1105 is out of bounds for axis 0 with size 985
# """
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 37
#      34 if f1_ood > 0:
#      36     dbcp_a = model._dbcp(X_id.values)
# ---> 37     dbcp_b = model._dbcp(X_b.values)
#      39     mssf_a = model.sufficiency_based_feature_importances(X_id.values)
#      40     mssf_b = model.sufficiency_based_feature_importances(X_b.values)
#
# File ~/github/mixed/ud_bagging.py:265, in InterpretableBaggingClassifier._dbcp(self, X)
#     261 # Parallel loop
#     262 n_jobs, n_estimators, starts = _partition_estimators(self.n_estimators,
#     263                                                      self.n_jobs)
# --> 265 all_importances = Parallel(n_jobs=n_jobs, verbose=self.verbose,
#     266                            **self._parallel_args())(
#     267     delayed(parallel_compute_feature_importances)(
#     268         self.estimators_[starts[i]:starts[i + 1]],
#     269         self.estimators_features_[starts[i]:starts[i + 1]],
#     270         self.n_features_in_,
#     271         sufficiency_based=False,
#     272         X=X)
#     273     for i in range(n_jobs))
#     275 # Reduce
#     276 importances = sum(all_importances) / self.n_estimators
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File ~/github/mixed/.venv/lib/python3.9/site-packages/joblib/parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# IndexError: index 1105 is out of bounds for axis 0 with size 985

# %%
df_result['acc']
# Out:
#                                                                Strategy  \
#                                    Dataset       ID       OOD         1
# assistments                    ASSISTments      NaN       NaN       NaN
# nhanes_lead                 Childhood Lead      NaN       NaN       NaN
# college_scorecard        College Scorecard      NaN       NaN       NaN
# brfss_diabetes                    Diabetes      NaN       NaN       NaN
# heloc                           FICO HELOC      NaN       NaN       NaN
# acsfoodstamps                  Food Stamps      NaN       NaN       NaN
# diabetes_readmission  Hospital Readmission      NaN       NaN       NaN
# brfss_blood_pressure          Hypertension      NaN       NaN       NaN
# acsincome                           Income      NaN       NaN       NaN
# physionet                           Sepsis      NaN       NaN       NaN
# acsunemployment               Unemployment      NaN       NaN       NaN
# anes                                Voting  0.56092  0.634968  0.610852
#
#
#                              2         3         4
# assistments                NaN       NaN       NaN
# nhanes_lead                NaN       NaN       NaN
# college_scorecard          NaN       NaN       NaN
# brfss_diabetes             NaN       NaN       NaN
# heloc                      NaN       NaN       NaN
# acsfoodstamps              NaN       NaN       NaN
# diabetes_readmission       NaN       NaN       NaN
# brfss_blood_pressure       NaN       NaN       NaN
# acsincome                  NaN       NaN       NaN
# physionet                  NaN       NaN       NaN
# acsunemployment            NaN       NaN       NaN
# anes                  0.610899  0.624653  0.624653

# %%
df_result['f-1']
# Out:
#                                                                Strategy  \
#                                    Dataset        ID       OOD        1
# assistments                    ASSISTments       NaN       NaN      NaN
# nhanes_lead                 Childhood Lead       NaN       NaN      NaN
# college_scorecard        College Scorecard       NaN       NaN      NaN
# brfss_diabetes                    Diabetes       NaN       NaN      NaN
# heloc                           FICO HELOC       NaN       NaN      NaN
# acsfoodstamps                  Food Stamps       NaN       NaN      NaN
# diabetes_readmission  Hospital Readmission       NaN       NaN      NaN
# brfss_blood_pressure          Hypertension       NaN       NaN      NaN
# acsincome                           Income       NaN       NaN      NaN
# physionet                           Sepsis       NaN       NaN      NaN
# acsunemployment               Unemployment       NaN       NaN      NaN
# anes                                Voting  0.608125  0.680781   0.5869
#
#
#                              2         3         4
# assistments                NaN       NaN       NaN
# nhanes_lead                NaN       NaN       NaN
# college_scorecard          NaN       NaN       NaN
# brfss_diabetes             NaN       NaN       NaN
# heloc                      NaN       NaN       NaN
# acsfoodstamps              NaN       NaN       NaN
# diabetes_readmission       NaN       NaN       NaN
# brfss_blood_pressure       NaN       NaN       NaN
# acsincome                  NaN       NaN       NaN
# physionet                  NaN       NaN       NaN
# acsunemployment            NaN       NaN       NaN
# anes                  0.586888  0.617188  0.667307
